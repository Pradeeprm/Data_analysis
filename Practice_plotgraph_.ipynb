# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np 
sns.set_theme(style="darkgrid")

# %%
tips=sns.load_dataset("tips")
tips
sns.relplot(x="total_bill",y="tip", data=tips)

# %%
sns.relplot(x="total_bill",y="tip",hue="sex",palette=["r","b"],data=tips)

# %%
from pylab import randn

# %%
languages=["Java","Python","PHP","Javasript","C#","c"]
Papularity=[22.2, 17.6, 8.8, 8, 7.7, 6.7]
explode=[0,0,0,0,0,0]
plt.pie(Papularity,explode=explode,labels=languages,shadow=True,startangle=45)
plt.axis("equal")
plt.legend(title="list of languages")
plt.show()

# %%
languages=["Java","Python","PHP","Javasript","C#","c"]
Papularity=[22.2, 17.6, 8.8, 8, 7.7, 6.7]
sns.relplot(x=languages,y=Papularity)

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x="total_bill",y="tip",hue="sex",style="day",palette=["r","b"],data=tips)

# %%
languages=["Java","Python","PHP","Javasript","C#","c"]
Papularity=[22.2, 17.6, 8.8, 8, 7.7, 6.7]
ax=sns.barplot(x=languages, y=Papularity )
plt.plot([], [], label = '22.2')
plt.plot([], [], label = '17.6')
plt.plot([], [], label = '8.8')
plt.plot([], [], label = '8')
plt.plot([], [], label = '7.7')
plt.plot([], [], label = '6.7')
plt.title("Papularity of languages")
plt.legend()
